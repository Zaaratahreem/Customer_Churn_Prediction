# %%
import pandas as pd
df = pd.read_csv("../Data/telco_churn_to_predict.csv")
df.head()
df.shape
df.columns
df.info()
df.isnull().sum()
df['churn_label'].value_counts()
df['churn_label'].value_counts(normalize=True) * 100
cat_cols = df.select_dtypes(include='object').columns
num_cols = df.select_dtypes(exclude='object').columns

print("Categorical Columns:")
print(cat_cols)

print("\nNumerical Columns:")
print(num_cols)
df[num_cols].dtypes
df[num_cols] = df[num_cols].fillna(df[num_cols].median())
df[cat_cols] = df[cat_cols].fillna("Unknown")
df_encoded = pd.get_dummies(df, drop_first=True)
df_encoded.shape
df.isnull().sum().sort_values(ascending=False)
df[num_cols] = df[num_cols].fillna(df[num_cols].median())
df[cat_cols] = df[cat_cols].fillna("Unknown")
df_encoded = pd.get_dummies(df, drop_first=True)
print(df.columns)

df = df.drop(['customer_id', 'count'], axis=1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 39 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   customer_id                        20 non-null     object
#  1   count                              20 non-null     int64
#  2   gender                             20 non-null     object
#  3   age                                20 non-null     int64
#  4   under_30                           20 non-null     object
#  5   senior_citizen                     20 non-null     object
#  6   married                            20 non-null     object
#  7   dependents                         20 non-null     object
#  8   number_of_dependents               20 non-null     int64
#  9   referred_a_friend                  20 non-null     object
#  10  number_of_referrals                20 non-null     int64
#  11  tenure_in_months                   20 non-null     int64
#  12  offer                              7 non-null      object
#  13  phone_service                      20 non-null     object
#  14  avg_monthly_long_distance_charges  20 non-null     float64
#  15  multiple_lines                     20 non-null     object
#  16  internet_service                   20 non-null     object
#  17  internet_type                      18 non-null     object
#  18  avg_monthly_gb_download            20 non-null     int64
#  19  online_security                    20 non-null     object
#  20  online_backup                      20 non-null     object
#  21  device_protection_plan             20 non-null     object
#  22  premium_tech_support               20 non-null     object
#  23  streaming_tv                       20 non-null     object
#  24  streaming_movies                   20 non-null     object
#  25  streaming_music                    20 non-null     object
#  26  unlimited_data                     20 non-null     object
#  27  contract                           20 non-null     object
#  28  paperless_billing                  20 non-null     object
#  29  payment_method                     20 non-null     object
#  30  monthly_charge                     20 non-null     float64
#  31  total_charges                      20 non-null     float64
#  32  total_refunds                      20 non-null     int64
#  33  total_extra_data_charges           20 non-null     int64
#  34  total_long_distance_charges        20 non-null     float64
#  35  total_revenue                      20 non-null     float64
#  36  satisfaction_score                 20 non-null     int64
#  37  cltv                               20 non-null     int64
#  38  churn_label                        20 non-null     object
# dtypes: float64(5), int64(10), object(24)
# memory usage: 6.2+ KB
# Categorical Columns:
# Index(['customer_id', 'gender', 'under_30', 'senior_citizen', 'married',
#        'dependents', 'referred_a_friend', 'offer', 'phone_service',
#        'multiple_lines', 'internet_service', 'internet_type',
#        'online_security', 'online_backup', 'device_protection_plan',
#        'premium_tech_support', 'streaming_tv', 'streaming_movies',
#        'streaming_music', 'unlimited_data', 'contract', 'paperless_billing',
#        'payment_method', 'churn_label'],
#       dtype='object')
#
# Numerical Columns:
# Index(['count', 'age', 'number_of_dependents', 'number_of_referrals',
#        'tenure_in_months', 'avg_monthly_long_distance_charges',
#        'avg_monthly_gb_download', 'monthly_charge', 'total_charges',
#        'total_refunds', 'total_extra_data_charges',
#        'total_long_distance_charges', 'total_revenue', 'satisfaction_score',
#        'cltv'],
#       dtype='object')
# Index(['customer_id', 'count', 'gender', 'age', 'under_30', 'senior_citizen',
#        'married', 'dependents', 'number_of_dependents', 'referred_a_friend',
#        'number_of_referrals', 'tenure_in_months', 'offer', 'phone_service',
#        'avg_monthly_long_distance_charges', 'multiple_lines',
#        'internet_service', 'internet_type', 'avg_monthly_gb_download',
#        'online_security', 'online_backup', 'device_protection_plan',
#        'premium_tech_support', 'streaming_tv', 'streaming_movies',
#        'streaming_music', 'unlimited_data', 'contract', 'paperless_billing',
#        'payment_method', 'monthly_charge', 'total_charges', 'total_refunds',
#        'total_extra_data_charges', 'total_long_distance_charges',
#        'total_revenue', 'satisfaction_score', 'cltv', 'churn_label'],
#       dtype='object')
